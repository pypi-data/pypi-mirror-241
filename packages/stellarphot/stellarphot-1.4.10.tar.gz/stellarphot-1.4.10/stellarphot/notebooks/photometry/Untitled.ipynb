# %%
from astroquery.mast import Catalogs

# %%
TIC_ID = 237205154
catalog_data = Catalogs.query_criteria(catalog="Tic", ID=TIC_ID)

# %%
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive
NasaExoplanetArchive.query_object("K2-18 b")
# Out:
# <QTable masked=True length=10>
# pl_name pl_letter hostname hd_name hip_name ... sy_kmag sy_kmagerr1 sy_kmagerr2      sky_coord
#                                             ...   mag       mag         mag           deg,deg
#   str7     str1     str5     str1    str1   ... float64   float64     float64         SkyCoord
# ------- --------- -------- ------- -------- ... ------- ----------- ----------- --------------------
# K2-18 b         b    K2-18                  ...   8.899       0.019      -0.019 172.560141,7.5878315
# K2-18 b         b    K2-18                  ...   8.899       0.019      -0.019 172.560141,7.5878315
# K2-18 b         b    K2-18                  ...   8.899       0.019      -0.019 172.560141,7.5878315
# K2-18 b         b    K2-18                  ...   8.899       0.019      -0.019 172.560141,7.5878315
# K2-18 b         b    K2-18                  ...   8.899       0.019      -0.019 172.560141,7.5878315
# ...

# %%
catalog_data['d']
# Out:
# <MaskedColumn name='d' dtype='float64' length=1>
# 686.482

# %%
catalog_data_more = Catalogs.query_criteria(catalog="ctl", ID=TIC_ID)
# Out:
# WARNING: NoResultsWarning: Query returned no results. [astroquery.mast.discovery_portal]

# %%
from astropy.nddata import CCDData

# %%
ccd = CCDData.read("../TIC_237205154.01-S001-R013-C001-rp.fit")
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / Equatorial coordinate system
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]

# %%
ccd.header["object"]#.split("T")[0].replace("-", "")
# Out:
# 'TIC-237205154'

# %%
from matplotlib import pyplot as plt

# %%
foo = plt.figure()

# %%
foo.savefig
