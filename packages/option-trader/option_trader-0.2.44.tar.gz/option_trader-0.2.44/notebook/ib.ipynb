# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import *
from ibapi.wrapper import *

class TestApp(EClient, EWrapper):
    def __init__(self):
        EClient.__init__(self, self)

    def nextValidId(self, orderId: int):
        
        mycontract = Contract()
        mycontract.symbol = "AAPL"
        mycontract.secType = "STK"
        mycontract.exchange = "SMART"
        mycontract.currency = "USD"

        self.reqMarketDataType(3)
        
        self.reqSecDefOptParams(0,"AAPL", "STK", "", 265598)        
#        self.reqHistoricalData(orderId, mycontract, "20230505 09:30:00 US/Eastern", "1 D", "1 hour", "TRADES", 0, 1, 0, [])

    def historicalData(self, reqId, bar):
        print(f"Historical Data: {bar}")

    def historicalDataEnd(self, reqId, start, end):
        print(f"End of HistoricalData")
        print(f"Start: {start}, End: {end}")


app = TestApp()
app.connect("127.0.0.1", 7497, 0)
app.run()

# %%
import pandas as pd
import yfinance as yf
period = '50y'
interval = '1d'
symbol = 'USDCNY=X'

int_index = ['^DJI','^GSPC','^IXIC','^SOX','^N225','^HSI','^GDAXI','^FTSE','^FCHI','^STI', '^RUT', '^KS11']
currency = ['USDJPY=X', 'USDJPY=X', 'USDEUR=X', 'USDHKD=X', 'USDCAD=X', 'USDAUD=X', 'USDGBP=X' ]
bond_list = ['^TNX', '^TYX']
commodity_list = ['CL=F','HO=F','NG=F','GC=F','PL=F','SI=F','HG=F','PA=F','ZC=F','ZS=F','ZL=F','HE=F','LE=F','CC=F','KC=F','CT=F','OJ=F','SB=F']

total_list = int_index + currency + bond_list + commodity_list


new_list = ['SPX', '^KS11', '^BSESN' ]

symbol='^BSESN'
q = yf.Ticker(symbol)
hist = q.history(period=period, interval=interval)
hist
#hist.to_csv('c:\\data\\'+symbol+'.csv', sep=',')
    
for symbol in new_list:
    q = yf.Ticker(symbol)
    hist = q.history(period=period, interval=interval)
    hist.to_csv('c:\\data\\'+symbol+'.csv', sep=',')

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        self.reqMarketDataType(3)
        
    def tickPrice(self, reqId, tickType, price, attrib):
        #if tickType == 2 and reqId == 1:       
        print('The current ask price is: ', price)

def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

#Create contract object
apple_contract = Contract()
apple_contract.symbol = 'MSFT'
apple_contract.secType = 'STK'
apple_contract.exchange = 'SMART'
apple_contract.currency = 'USD'

#Request Market Data
app.reqMarketDataType(3)
app.reqMktData(1, apple_contract, '', False, False, [])

time.sleep(10) #Sleep interval to allow time for incoming price data
app.disconnect()
# Out:
# ERROR -1 504 Not connected
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# ERROR 1 10167 Requested market data is not subscribed. Displaying delayed market data.
# The current ask price is:  335.1
# The current ask price is:  337.5
# The current ask price is:  332.55
# The current ask price is:  332.58
# The current ask price is:  -1.0
# The current ask price is:  -1.0
# The current ask price is:  0.0

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
#from ibapi.contract import Contract
from ibapi.common import SetOfString
from ibapi.common import SetOfFloat

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        
        
    def securityDefinitionOptionParameter(self, 
                                          reqId:int, 
                                          exchange:str, 
                                          underlyingConId:int, 
                                          tradingClass:str, 
                                          multiplier:str, 
                                          expirations:SetOfString, 
                                          strikes:SetOfFloat):
        print("SecurityDefinitionOptionParameter.", "ReqId:", 
              reqId, "Exchange:", 
              exchange, "Underlying conId:", 
              underlyingConId, "TradingClass:", 
              tradingClass, "Multiplier:", 
              multiplier, "Expirations:", 
              expirations, "Strikes:", 
              str(strikes),"\n")

    def securityDefinitionOptionParameterEnd(self, reqId:int):

        print("SecurityDefinitionOptionParameterEnd. ReqId:", reqId)

def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

app.reqSecDefOptParams(0,"MSFT", "", "STK", 272093)

time.sleep(10) #Sleep interval to allow time for incoming price data
app.disconnect()
# Out:
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: AMEX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: BOX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: CBOE2 Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: BATS Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: EMERALD Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: PHLX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: NASDAQOM Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: PSE Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: NASDAQBX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: SMART Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: GEMINI Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: ISE Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: MIAX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: PEARL Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: IBUSOPT Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: EDGX Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: CBOE Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameter. ReqId: 0 Exchange: MERCURY Underlying conId: 272093 TradingClass: MSFT Multiplier: 100 Expirations: {'20240621', '20230714', '20231215', '20231020', '20230915', '20251219', '20240119', '20230616', '20230707', '20250620', '20230630', '20231117', '20230818', '20241220', '20240315', '20230623', '20230609', '20230721', '20250117'} Strikes: {520.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0, 185.0, 190.0, 195.0, 200.0, 205.0, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 272.5, 275.0, 277.5, 280.0, 282.5, 285.0, 287.5, 290.0, 292.5, 295.0, 297.5, 300.0, 302.5, 305.0, 307.5, 310.0, 312.5, 315.0, 317.5, 320.0, 322.5, 325.0, 327.5, 330.0, 332.5, 335.0, 337.5, 340.0, 342.5, 345.0, 347.5, 350.0, 352.5, 355.0, 357.5, 360.0, 362.5, 365.0, 367.5, 370.0, 372.5, 375.0, 377.5, 380.0, 385.0, 390.0, 395.0, 400.0, 405.0, 410.0, 415.0, 420.0, 425.0, 430.0, 435.0, 440.0, 445.0, 450.0, 455.0, 460.0, 465.0, 470.0, 475.0, 480.0, 485.0, 490.0, 495.0, 500.0}
#
# SecurityDefinitionOptionParameterEnd. ReqId: 0

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract, ContractDetails
from ibapi.common import SetOfString
from ibapi.common import SetOfFloat

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        
        
    def contractDetails(self, reqId: int, contractDetails: ContractDetails):
        super().contractDetails(reqId, contractDetails)
        print(contractDetails)
        #printinstance(contractDetails)

    def contractDetailsEnd(self, reqId: int):
        super().contractDetailsEnd(reqId)
        print("ContractDetailsEnd. ReqId:", reqId)

def run_loop():
    app.run()

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

contract = Contract()
contract.symbol = 'AAPL'
contract.secType = "OPT"
contract.exchange = "SMART"
contract.currency = "USD"
      
x = app.reqContractDetails(0, contract)
time.sleep(10) #Sleep interval to allow time for incoming price data
#print(x)
app.disconnect()
# Out:
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil

# %%
from ibapi.ticktype import TickTypeEnum

for i in range(91):
	print(TickTypeEnum.to_str(i), i)
# Out:
# BID_SIZE 0
# BID 1
# ASK 2
# ASK_SIZE 3
# LAST 4
# LAST_SIZE 5
# HIGH 6
# LOW 7
# VOLUME 8
# CLOSE 9
# BID_OPTION_COMPUTATION 10
# ASK_OPTION_COMPUTATION 11
# LAST_OPTION_COMPUTATION 12
# MODEL_OPTION 13
# OPEN 14
# LOW_13_WEEK 15
# HIGH_13_WEEK 16
# LOW_26_WEEK 17
# HIGH_26_WEEK 18
# LOW_52_WEEK 19
# HIGH_52_WEEK 20
# AVG_VOLUME 21
# OPEN_INTEREST 22
# OPTION_HISTORICAL_VOL 23
# OPTION_IMPLIED_VOL 24
# OPTION_BID_EXCH 25
# OPTION_ASK_EXCH 26
# OPTION_CALL_OPEN_INTEREST 27
# OPTION_PUT_OPEN_INTEREST 28
# OPTION_CALL_VOLUME 29
# OPTION_PUT_VOLUME 30
# INDEX_FUTURE_PREMIUM 31
# BID_EXCH 32
# ASK_EXCH 33
# AUCTION_VOLUME 34
# AUCTION_PRICE 35
# AUCTION_IMBALANCE 36
# MARK_PRICE 37
# BID_EFP_COMPUTATION 38
# ASK_EFP_COMPUTATION 39
# LAST_EFP_COMPUTATION 40
# OPEN_EFP_COMPUTATION 41
# HIGH_EFP_COMPUTATION 42
# LOW_EFP_COMPUTATION 43
# CLOSE_EFP_COMPUTATION 44
# LAST_TIMESTAMP 45
# SHORTABLE 46
# FUNDAMENTAL_RATIOS 47
# RT_VOLUME 48
# HALTED 49
# BID_YIELD 50
# ASK_YIELD 51
# LAST_YIELD 52
# CUST_OPTION_COMPUTATION 53
# TRADE_COUNT 54
# TRADE_RATE 55
# VOLUME_RATE 56
# LAST_RTH_TRADE 57
# RT_HISTORICAL_VOL 58
# IB_DIVIDENDS 59
# BOND_FACTOR_MULTIPLIER 60
# REGULATORY_IMBALANCE 61
# NEWS_TICK 62
# SHORT_TERM_VOLUME_3_MIN 63
# SHORT_TERM_VOLUME_5_MIN 64
# SHORT_TERM_VOLUME_10_MIN 65
# DELAYED_BID 66
# DELAYED_ASK 67
# DELAYED_LAST 68
# DELAYED_BID_SIZE 69
# DELAYED_ASK_SIZE 70
# DELAYED_LAST_SIZE 71
# DELAYED_HIGH 72
# DELAYED_LOW 73
# DELAYED_VOLUME 74
# DELAYED_CLOSE 75
# DELAYED_OPEN 76
# RT_TRD_VOLUME 77
# CREDITMAN_MARK_PRICE 78
# CREDITMAN_SLOW_MARK_PRICE 79
# DELAYED_BID_OPTION 80
# DELAYED_ASK_OPTION 81
# DELAYED_LAST_OPTION 82
# DELAYED_MODEL_OPTION 83
# LAST_EXCH 84
# LAST_REG_TIME 85
# FUTURES_OPEN_INTEREST 86
# AVG_OPT_VOLUME 87
# DELAYED_LAST_TIMESTAMP 88
# SHORTABLE_SHARES 89
# DELAYED_HALTED 90

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract
from threading import Timer

class TestApp(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)

    #def error(self, reqId, errorCode, errorString):
    #    print("Error: ", reqId, " ", errorCode, " ", errorString)

    def nextValidId(self, orderId):
        self.start()

    def updatePortfolio(self, contract: Contract, position: float, marketPrice: float, marketValue: float,
                        averageCost: float, unrealizedPNL: float, realizedPNL: float, accountName: str):
        print("UpdatePortfolio.", "Symbol:", contract.symbol, "SecType:", contract.secType, "Exchange:", contract.exchange,
              "Position:", position, "MarketPrice:", marketPrice, "MarketValue:", marketValue, "AverageCost:", averageCost,
              "UnrealizedPNL:", unrealizedPNL, "RealizedPNL:", realizedPNL, "AccountName:", accountName)

    def updateAccountValue(self, key: str, val: str, currency: str, accountName: str):
        print("UpdateAccountValue. Key:", key, "Value:", val, "Currency:", currency, "AccountName:", accountName)

    def updateAccountTime(self, timeStamp: str):
        print("UpdateAccountTime. Time:", timeStamp)

    def accountDownloadEnd(self, accountName: str):
        print("AccountDownloadEnd. Account:", accountName)

    def start(self):
        # Account number can be omitted when using reqAccountUpdates with single account structure
        self.reqAccountUpdates(True, "")

    def stop(self):
        self.reqAccountUpdates(False, "")
        self.done = True
        self.disconnect()

def main():
    app = TestApp()
    app.connect("127.0.0.1", 7497, 0)

    Timer(5, app.stop).start()
    app.run()

if __name__ == "__main__":
    main()
# Out:
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:fundfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefil
# UpdateAccountValue. Key: AccountCode Value: DU7131629 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: AccountOrGroup Value: DU7131629 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: AccountOrGroup Value: DU7131629 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: AccountOrGroup Value: DU7131629 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AccountReady Value: true Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: AccountType Value: INDIVIDUAL Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: AccruedCash Value: 3030.4834715 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: AccruedCash Value: 455.07 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: AccruedCash Value: 2543.24 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AccruedCash-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AccruedCash-S Value: 3030.48 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AccruedDividend Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AccruedDividend-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AccruedDividend-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AvailableFunds Value: 914484.05 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AvailableFunds-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: AvailableFunds-S Value: 914484.05 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Billable Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Billable-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Billable-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: BuyingPower Value: 3657936.21 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: CashBalance Value: 758172.9198 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: CashBalance Value: 400000.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: CashBalance Value: 329892.90 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: ColumnPrio-C Value: 2 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: ColumnPrio-S Value: 1 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: CorporateBondValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: CorporateBondValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: CorporateBondValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Currency Value: BASE Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: Currency Value: EUR Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: Currency Value: USD Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Cushion Value: 0.916275 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: DayTradesRemaining Value: -1 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: DayTradesRemainingT+1 Value: -1 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: DayTradesRemainingT+2 Value: -1 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: DayTradesRemainingT+3 Value: -1 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: DayTradesRemainingT+4 Value: -1 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: EquityWithLoanValue Value: 1003794.92 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: EquityWithLoanValue-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: EquityWithLoanValue-S Value: 1003794.92 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: ExcessLiquidity Value: 922611.41 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: ExcessLiquidity-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: ExcessLiquidity-S Value: 922611.41 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: ExchangeRate Value: 1.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: ExchangeRate Value: 1.0707 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: ExchangeRate Value: 1.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullAvailableFunds Value: 914484.05 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullAvailableFunds-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullAvailableFunds-S Value: 914484.05 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullExcessLiquidity Value: 922611.41 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullExcessLiquidity-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullExcessLiquidity-S Value: 922611.41 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullInitMarginReq Value: 89310.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullInitMarginReq-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullInitMarginReq-S Value: 89310.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullMaintMarginReq Value: 81183.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullMaintMarginReq-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FullMaintMarginReq-S Value: 81183.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FundValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: FundValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: FundValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FutureOptionValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: FutureOptionValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: FutureOptionValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FuturesPNL Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: FuturesPNL Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: FuturesPNL Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: FxCashBalance Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: FxCashBalance Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: FxCashBalance Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: GrossPositionValue Value: 296818.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: GrossPositionValue-S Value: 296818.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Guarantee Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Guarantee-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Guarantee-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: IndianStockHaircut Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: IndianStockHaircut-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: IndianStockHaircut-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: InitMarginReq Value: 89310.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: InitMarginReq-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: InitMarginReq-S Value: 89310.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: IssuerOptionValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: IssuerOptionValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: IssuerOptionValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: Leverage-S Value: 0.29 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadAvailableFunds Value: 914484.05 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadAvailableFunds-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadAvailableFunds-S Value: 914484.05 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadExcessLiquidity Value: 922611.41 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadExcessLiquidity-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadExcessLiquidity-S Value: 922611.41 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadInitMarginReq Value: 89310.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadInitMarginReq-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadInitMarginReq-S Value: 89310.86 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadMaintMarginReq Value: 81183.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadMaintMarginReq-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadMaintMarginReq-S Value: 81183.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: LookAheadNextChange Value: 0 Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: MaintMarginReq Value: 81183.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: MaintMarginReq-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: MaintMarginReq-S Value: 81183.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: MoneyMarketFundValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: MoneyMarketFundValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: MoneyMarketFundValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: MutualFundValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: MutualFundValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: MutualFundValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: NLVAndMarginInReview Value: false Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: NetDividend Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: NetDividend Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: NetDividend Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: NetLiquidation Value: 1006915.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: NetLiquidation-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: NetLiquidation-S Value: 1006915.50 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: NetLiquidationByCurrency Value: 1006915.4967 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: NetLiquidationByCurrency Value: 400455.07 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: NetLiquidationByCurrency Value: 578148.2335 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: NetLiquidationUncertainty Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: OptionMarketValue Value: 90.09 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: OptionMarketValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: OptionMarketValue Value: 90.09 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PASharesValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PASharesValue-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PASharesValue-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PhysicalCertificateValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PhysicalCertificateValue-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PhysicalCertificateValue-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PostExpirationExcess Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PostExpirationExcess-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PostExpirationExcess-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PostExpirationMargin Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PostExpirationMargin-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PostExpirationMargin-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PreviousDayEquityWithLoanValue Value: 1002356.88 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: PreviousDayEquityWithLoanValue-S Value: 1002356.88 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: RealCurrency Value: BASE Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: RealCurrency Value: EUR Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: RealCurrency Value: USD Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: RealizedPnL Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: RealizedPnL Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: RealizedPnL Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: RegTEquity Value: 1006825.40 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: RegTEquity-S Value: 1006825.40 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: RegTMargin Value: 148101.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: RegTMargin-S Value: 148101.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: SMA Value: 858724.40 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: SMA-S Value: 858724.40 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: SegmentTitle-C Value: US Commodities Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: SegmentTitle-S Value: US Securities Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: StockMarketValue Value: 245622.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: StockMarketValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: StockMarketValue Value: 245622.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TBillValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: TBillValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: TBillValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TBondValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: TBondValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: TBondValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TotalCashBalance Value: 758172.9198 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: TotalCashBalance Value: 400000.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: TotalCashBalance Value: 329892.90 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TotalCashValue Value: 758172.92 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TotalCashValue-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TotalCashValue-S Value: 758172.92 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TotalDebitCardPendingCharges Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TotalDebitCardPendingCharges-C Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TotalDebitCardPendingCharges-S Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: TradingType-S Value: STKNOPT Currency:  AccountName: DU7131629
# UpdateAccountValue. Key: UnrealizedPnL Value: 17503.97 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: UnrealizedPnL Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: UnrealizedPnL Value: 17503.97 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: WarrantValue Value: 0.00 Currency: BASE AccountName: DU7131629
# UpdateAccountValue. Key: WarrantValue Value: 0.00 Currency: EUR AccountName: DU7131629
# UpdateAccountValue. Key: WarrantValue Value: 0.00 Currency: USD AccountName: DU7131629
# UpdateAccountValue. Key: WhatIfPMEnabled Value: true Currency:  AccountName: DU7131629
# UpdatePortfolio. Symbol: AMZN SecType: OPT Exchange:  Position: -4 MarketPrice: 0.0261572 MarketValue: -10.46 AverageCost: 82.54785 UnrealizedPNL: 319.73 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: AMZN SecType: OPT Exchange:  Position: 4 MarketPrice: 0.1123396 MarketValue: 44.94 AverageCost: 390.44905 UnrealizedPNL: -1516.86 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: AVGO SecType: OPT Exchange:  Position: -150 MarketPrice: 0.016268 MarketValue: -244.02 AverageCost: 370.77547265 UnrealizedPNL: 55372.3 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: AVGO SecType: OPT Exchange:  Position: 150 MarketPrice: 0.0191793 MarketValue: 287.69 AverageCost: 470.5234 UnrealizedPNL: -70290.82 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: BABA SecType: STK Exchange:  Position: -300 MarketPrice: 84.30000305 MarketValue: -25290.0 AverageCost: 89.0 UnrealizedPNL: 1410.0 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: BABA SecType: OPT Exchange:  Position: 0 MarketPrice: 0.0 MarketValue: 0.0 AverageCost: 0.0 UnrealizedPNL: 0.0 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: BABA SecType: OPT Exchange:  Position: 0 MarketPrice: 4.73000335 MarketValue: 0.0 AverageCost: 0.0 UnrealizedPNL: 0.0 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: MA SecType: STK Exchange:  Position: 100 MarketPrice: 372.7200012 MarketValue: 37272.0 AverageCost: 382.54 UnrealizedPNL: -982.0 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: MSFT SecType: STK Exchange:  Position: 100 MarketPrice: 335.1499939 MarketValue: 33515.0 AverageCost: 312.338904 UnrealizedPNL: 2281.11 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: NFLX SecType: STK Exchange:  Position: 500 MarketPrice: 400.25 MarketValue: 200125.0 AverageCost: 333.9894 UnrealizedPNL: 33130.3 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: NOW SecType: OPT Exchange:  Position: 0 MarketPrice: 0.0 MarketValue: 0.0 AverageCost: 0.0 UnrealizedPNL: 0.0 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: NOW SecType: OPT Exchange:  Position: 0 MarketPrice: 0.0 MarketValue: 0.0 AverageCost: 0.0 UnrealizedPNL: 0.0 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: NVDA SecType: OPT Exchange:  Position: -5 MarketPrice: 0.008593 MarketValue: -4.3 AverageCost: 1254.67848 UnrealizedPNL: 6269.1 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: NVDA SecType: OPT Exchange:  Position: 5 MarketPrice: 0.01254975 MarketValue: 6.27 AverageCost: 1510.30906 UnrealizedPNL: -7545.27 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: TSM SecType: OPT Exchange:  Position: -4 MarketPrice: 0.0115071 MarketValue: -4.6 AverageCost: 29.675775 UnrealizedPNL: 114.1 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdatePortfolio. Symbol: TSM SecType: OPT Exchange:  Position: 4 MarketPrice: 0.03644305 MarketValue: 14.58 AverageCost: 268.07155 UnrealizedPNL: -1057.71 RealizedPNL: 0.0 AccountName: DU7131629
# UpdateAccountTime. Time: 07:29
# UpdateAccountTime. Time: 07:42
# AccountDownloadEnd. Account: DU7131629

# %%
class TestApp(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)

    def error(self, reqId, errorCode, errorString):
        print("Error: ", reqId, " ", errorCode, " ", errorString)

    def nextValidId(self, orderId):
        self.start()

    def updatePortfolio(self, contract: Contract, position: float, marketPrice: float, marketValue: float,
                        averageCost: float, unrealizedPNL: float, realizedPNL: float, accountName: str):
        print("UpdatePortfolio.", "Symbol:", contract.symbol, "SecType:", contract.secType, "Exchange:", contract.exchange,
              "Position:", position, "MarketPrice:", marketPrice, "MarketValue:", marketValue, "AverageCost:", averageCost,
              "UnrealizedPNL:", unrealizedPNL, "RealizedPNL:", realizedPNL, "AccountName:", accountName)

    def updateAccountValue(self, key: str, val: str, currency: str, accountName: str):
        print("UpdateAccountValue. Key:", key, "Value:", val, "Currency:", currency, "AccountName:", accountName)

    def updateAccountTime(self, timeStamp: str):
        print("UpdateAccountTime. Time:", timeStamp)

    def accountDownloadEnd(self, accountName: str):
        print("AccountDownloadEnd. Account:", accountName)

    def start(self):
        # Account number can be omitted when using reqAccountUpdates with single account structure
        self.reqAccountUpdates(True, "")

    def stop(self):
        self.reqAccountUpdates(False, "")
        self.done = True
        self.disconnect()

# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract

import threading
import time

class IBapi(EWrapper, EClient):
	def __init__(self):
		EClient.__init__(self, self)
	def historicalData(self, reqId, bar):
		print(f'Time: {bar.date} Close: {bar.close}')
		
def run_loop():
	app.run()

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

time.sleep(1) #Sleep interval to allow time for connection to server

#Create contract object
eurusd_contract = Contract()
eurusd_contract.symbol = 'EUR'
eurusd_contract.secType = 'CASH'
eurusd_contract.exchange = 'IDEALPRO'
eurusd_contract.currency = 'USD'

#Request historical candles
app.reqHistoricalData(1, eurusd_contract, '', '2 D', '1 hour', 'BID', 0, 2, False, [])

time.sleep(5) #sleep to allow enough time for data to be returned
app.disconnect()

# %%
import sys

sys.path.append(r'C:\TWS API\source\pythonclient')

from ibapi.client import EClient
from ibapi.wrapper import EWrapper
from ibapi.contract import Contract
from ibapi.order import *

import threading
import time

class IBapi(EWrapper, EClient):
	def __init__(self):
		EClient.__init__(self, self)

	def nextValidId(self, orderId: int):
		super().nextValidId(orderId)
		self.nextorderId = orderId
		print('The next valid order id is: ', self.nextorderId)

	def orderStatus(self, orderId, status, filled, remaining, avgFullPrice, permId, parentId, lastFillPrice, clientId, whyHeld, mktCapPrice):
		print('orderStatus - orderid:', orderId, 'status:', status, 'filled', filled, 'remaining', remaining, 'lastFillPrice', lastFillPrice)
	
	def openOrder(self, orderId, contract, order, orderState):
		print('openOrder id:', orderId, contract.symbol, contract.secType, '@', contract.exchange, ':', order.action, order.orderType, order.totalQuantity, orderState.status)

	def execDetails(self, reqId, contract, execution):
		print('Order Executed: ', reqId, contract.symbol, contract.secType, contract.currency, execution.execId, execution.orderId, execution.shares, execution.lastLiquidity)


def run_loop():
	app.run()

#Function to create FX Order contract
def FX_order(symbol):
	contract = Contract()
	contract.symbol = symbol[:3]
	contract.secType = 'CASH'
	contract.exchange = 'IDEALPRO'
	contract.currency = symbol[3:]
	return contract

app = IBapi()
app.connect('127.0.0.1', 7497, 123)

app.nextorderId = None

#Start the socket in a thread
api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()

#Check if the API is connected via orderid
while True:
	if isinstance(app.nextorderId, int):
		print('connected')
		break
	else:
		print('waiting for connection')
		time.sleep(1)

#Create order object
order = Order()
order.action = 'BUY'
order.totalQuantity = 100000
order.orderType = 'LMT'
order.lmtPrice = '1.10'

#Place order
app.placeOrder(app.nextorderId, FX_order('EURUSD'), order)
#app.nextorderId += 1

time.sleep(3)

#Cancel order 
print('cancelling order')
app.cancelOrder(app.nextorderId, "")

time.sleep(3)
app.disconnect()

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect('127.0.0.1', 7497, clientId=4)

contract = Forex('EURUSD')

x = ib.reqSecDefOptParams("AAPL", "", "STK", 265598)

print(x[0])

ib.disconnect()

# convert to pandas dataframe:
#df = util.df(bars)
#print(df)
# Out:
# OptionChain(exchange='CBOE', underlyingConId='265598', tradingClass='AAPL', multiplier='100', expirations=['20230609', '20230616', '20230623', '20230630', '20230707', '20230714', '20230721', '20230818', '20230915', '20231020', '20231117', '20231215', '20240119', '20240315', '20240621', '20240920', '20241220', '20250117', '20250620', '20251219'], strikes=[50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0, 90.0, 95.0, 100.0, 105.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 147.0, 148.0, 149.0, 150.0, 152.5, 155.0, 157.5, 160.0, 162.5, 165.0, 167.5, 170.0, 172.5, 175.0, 177.5, 180.0, 182.5, 185.0, 187.5, 190.0, 192.5, 195.0, 197.5, 200.0, 202.5, 205.0, 207.5, 210.0, 215.0, 220.0, 225.0, 230.0, 235.0, 240.0, 245.0, 250.0, 255.0, 260.0, 265.0, 270.0, 275.0, 280.0, 285.0, 290.0, 295.0, 300.0, 305.0, 310.0, 320.0])

# %%
x[0].expirations

# %%
from ib_insync import *

try:
    get_ipython    
    util.startLoop()  # uncomment this line when in a notebook
except:
    pass
    
ib = IB()

ib.connect('127.0.0.1', 7497, clientId=3)

# %%
from ib_insync import *
import numpy as np
import pandas as pd
from datetime import time, date, datetime, timedelta
from pytz import timezone

option_chain_rec = {'exp_date':[''],'strike':[np.nan],
                'lastPirce':[np.nan],'bid':[np.nan], 'ask':[np.nan],
                'bidSize':[np.nan], 'askSize':[np.nan], 'volume':[np.nan],
                'open':[np.nan], 'high':[np.nan], 'low':[np.nan], 'close':[np.nan],
                'impliedVolatility':[np.nan], 'delta':[np.nan], 'gamma':[np.nan],
                'vega':[np.nan], 'theta':[np.nan],'sigma':[np.nan]}

def get_option_chain(symbol, stock_price, strike_limit_pert =0.05, max_days_to_expire=30):
    
    trade_date = datetime.now(timezone('US/Eastern'))    
    
    util.startLoop()  # uncomment this line when in a notebook

    ib = IB()

    ib.connect('127.0.0.1', 7497, clientId=4)

    x = ib.reqMatchingSymbols(symbol)

    conId = x[0].contract.conId

    x = ib.reqSecDefOptParams(symbol, "", "STK", conId)

    exp_date_list = list(filter(lambda x: (pd.Timestamp(x).tz_localize(timezone('US/Eastern'))-trade_date).days < max_days_to_expire, x[0].expirations))   
   
    strikes = list(filter(lambda x: x >= stock_price * (1-strike_limit_pert) and x <= stock_price * (1+strike_limit_pert), x[0].strikes))   
    
    #df_new_row = pd.DataFrame.from_records(self.empty_rec)

    ib.reqMarketDataType(3)
        
    df = pd.DataFrame()
    for exp_date in exp_date_list:
        for strike in strikes:        
            print(exp_date, strike)
            contract = Contract()
            contract.symbol = symbol
            contract.secType = 'OPT'
            contract.exchange = 'SMART'
            contract.currency = 'USD'
            contract.lastTradeDateOrContractMonth = exp_date
            contract.strike = strike
            contract.right = 'C'
            contract.multiplier = '100'
            ib.qualifyContracts(contract) 
            x = ib.reqMktData(contract, '', False, False, [])
            ib.sleep(5)            
            ne = pd.DataFrame.from_records(option_chain_rec)
            ne.exp_date = exp_date
            ne.strike = strike    
            ne.bid =  x.bid
            ne.bidSize = x.bidSize
            ne.ask = x.ask
            ne.askSize = x.askSize
            ne.lastPrice = x.last
            ne.open = x.open
            ne.high = x.high
            ne.low = x.low
            ne.close = x.close
            
            if x.bidGreeks != None:
                ne.impliedVolatility = (x.bidGreeks.impliedVol + x.askGreeks.impliedVol) / 2
                ne.delta = (x.bidGreeks.delta + x.askGreeks.delta) / 2
                ne.gamma = (x.bidGreeks.gamma + x.askGreeks.gamma) / 2
                ne.vega =  (x.bidGreeks.vega + x.askGreeks.vega) / 2
                ne.theta = (x.bidGreeks.theta  + x.askGreeks.theta ) / 2
                ne.sigma = (x.bidGreeks.sigma  + x.askGreeks.sigma ) / 2
                ne.volume = x.volume

            df = pd.concat([df, ne])  
                        
    ib.disconnect()
    
    return df

df = get_option_chain('MSFT', 320)

df
# Out:
# 20230609 305.0
# Error 354, reqId 6: Requested market data is not subscribed.MSFT JUN 09 '23 305 Call/TOP/ALL, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# 20230609 307.5
# Error 10091, reqId 8: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632495696, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00307500', tradingClass='MSFT')
# 20230609 310.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 10: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=628270983, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=310.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00310000', tradingClass='MSFT')
# 20230609 312.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 12: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632495741, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00312500', tradingClass='MSFT')
# 20230609 315.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 14: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=628271043, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=315.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00315000', tradingClass='MSFT')
# 20230609 317.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 16: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632495793, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00317500', tradingClass='MSFT')
# 20230609 320.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 18: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=628271124, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=320.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00320000', tradingClass='MSFT')
# 20230609 322.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 20: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632495854, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00322500', tradingClass='MSFT')
# 20230609 325.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 22: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=628271182, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=325.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00325000', tradingClass='MSFT')
# 20230609 327.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 24: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632495916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00327500', tradingClass='MSFT')
# 20230609 330.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 26: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=628271254, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=330.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00330000', tradingClass='MSFT')
# 20230609 332.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 28: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632495966, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00332500', tradingClass='MSFT')
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# 20230609 335.0
# Error 10091, reqId 30: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=628271325, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=335.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00335000', tradingClass='MSFT')
# 20230616 305.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 32: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=474534287, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00305000', tradingClass='MSFT')
# 20230616 307.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 34: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632497130, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00307500', tradingClass='MSFT')
# 20230616 310.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 36: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=474534289, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=310.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00310000', tradingClass='MSFT')
# 20230616 312.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 38: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632497185, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00312500', tradingClass='MSFT')
# 20230616 315.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 40: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=474534292, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=315.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00315000', tradingClass='MSFT')
# 20230616 317.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 42: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632497263, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00317500', tradingClass='MSFT')
# 20230616 320.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 44: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=474534302, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=320.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00320000', tradingClass='MSFT')
# 20230616 322.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 46: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632497324, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00322500', tradingClass='MSFT')
# 20230616 325.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 48: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=474534311, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=325.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00325000', tradingClass='MSFT')
# 20230616 327.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 50: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632497389, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00327500', tradingClass='MSFT')
# 20230616 330.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 52: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=474534312, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=330.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00330000', tradingClass='MSFT')
# 20230616 332.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 54: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=632497445, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00332500', tradingClass='MSFT')
# 20230616 335.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 56: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=474534317, symbol='MSFT', lastTradeDateOrContractMonth='20230616', strike=335.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230616C00335000', tradingClass='MSFT')
# 20230623 305.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 58: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=629362570, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00305000', tradingClass='MSFT')
# 20230623 307.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 60: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=635107360, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00307500', tradingClass='MSFT')
# 20230623 310.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 62: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=629362628, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=310.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00310000', tradingClass='MSFT')
# 20230623 312.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 64: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=635107416, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00312500', tradingClass='MSFT')
# 20230623 315.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 66: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=629362700, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=315.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00315000', tradingClass='MSFT')
# 20230623 317.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 68: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=635107473, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00317500', tradingClass='MSFT')
# 20230623 320.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 70: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=629362784, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=320.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00320000', tradingClass='MSFT')
# 20230623 322.5
# Error 10091, reqId 72: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=635107507, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00322500', tradingClass='MSFT')
# 20230623 325.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 74: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=629362854, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=325.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00325000', tradingClass='MSFT')
# 20230623 327.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 76: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=635107558, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00327500', tradingClass='MSFT')
# 20230623 330.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 78: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=629362925, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=330.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00330000', tradingClass='MSFT')
# 20230623 332.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 80: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=635107608, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00332500', tradingClass='MSFT')
# 20230623 335.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 82: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=629362996, symbol='MSFT', lastTradeDateOrContractMonth='20230623', strike=335.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230623C00335000', tradingClass='MSFT')
# 20230630 305.0
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 10091, reqId 84: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=630481704, symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230630C00305000', tradingClass='MSFT')
# 20230630 307.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 200, reqId 85: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 86: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=307.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20230630 310.0
# Error 10091, reqId 88: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=630481778, symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=310.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230630C00310000', tradingClass='MSFT')
# 20230630 312.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 200, reqId 89: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 90: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=312.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20230630 315.0
# Error 10091, reqId 92: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=630481844, symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=315.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230630C00315000', tradingClass='MSFT')
# 20230630 317.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 200, reqId 93: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 94: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=317.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20230630 320.0
# Error 10091, reqId 96: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=630481928, symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=320.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230630C00320000', tradingClass='MSFT')
# 20230630 322.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 200, reqId 97: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 98: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=322.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20230630 325.0
# Error 10091, reqId 100: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=630482027, symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=325.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230630C00325000', tradingClass='MSFT')
# 20230630 327.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 200, reqId 101: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 102: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=327.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20230630 330.0
# Error 10091, reqId 104: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=630482105, symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=330.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230630C00330000', tradingClass='MSFT')
# 20230630 332.5
# Error 10197, reqId 6: No market data during competing live session, contract: Contract(secType='OPT', conId=628270916, symbol='MSFT', lastTradeDateOrContractMonth='20230609', strike=305.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230609C00305000', tradingClass='MSFT')
# Error 200, reqId 105: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Unknown contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# Error 200, reqId 106: No security definition has been found for the request, contract: Contract(secType='OPT', symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=332.5, right='C', multiplier='100', exchange='SMART', currency='USD')
# 20230630 335.0
# Error 10091, reqId 108: Part of requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.MSFT NASDAQ.NMS/TOP/ALL, contract: Contract(secType='OPT', conId=630482205, symbol='MSFT', lastTradeDateOrContractMonth='20230630', strike=335.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='MSFT  230630C00335000', tradingClass='MSFT')
#    ask  askSize  bid  bidSize  close  delta  exp_date  gamma   high
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230609    NaN    NaN  \
# 0  NaN      NaN  NaN      NaN  25.73    NaN  20230609    NaN  28.96
# 0 -1.0      0.0 -1.0      0.0  23.28    NaN  20230609    NaN  26.62
# 0 -1.0      0.0 -1.0      0.0  20.83    NaN  20230609    NaN  24.20
# 0 -1.0      0.0 -1.0      0.0  18.46    NaN  20230609    NaN  22.80
# 0  NaN      NaN  NaN      NaN  16.09    NaN  20230609    NaN  19.69
# 0  NaN      NaN  NaN      NaN  13.80    NaN  20230609    NaN  18.04
# 0  NaN      NaN  NaN      NaN  11.58    NaN  20230609    NaN  15.95
# 0  NaN      NaN  NaN      NaN   9.57    NaN  20230609    NaN  13.04
# 0  NaN      NaN  NaN      NaN   7.56    NaN  20230609    NaN  11.32
# 0 -1.0      0.0 -1.0      0.0   5.87    NaN  20230609    NaN   9.30
# 0  NaN      NaN  NaN      NaN   4.41    NaN  20230609    NaN   7.30
# 0  NaN      NaN  NaN      NaN   3.25    NaN  20230609    NaN   5.75
# 0  NaN      NaN  NaN      NaN  28.97    NaN  20230616    NaN  33.00
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230616    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  24.22    NaN  20230616    NaN  28.00
# 0 -1.0      0.0 -1.0      0.0  21.88    NaN  20230616    NaN  25.36
# 0 -1.0      0.0 -1.0      0.0  19.64    NaN  20230616    NaN  22.95
# 0  NaN      NaN  NaN      NaN  17.45    NaN  20230616    NaN  20.13
# 0  NaN      NaN  NaN      NaN  15.31    NaN  20230616    NaN  19.25
# 0  NaN      NaN  NaN      NaN  13.20    NaN  20230616    NaN  16.90
# 0 -1.0      0.0 -1.0      0.0  11.20    NaN  20230616    NaN  14.69
# 0 -1.0      0.0 -1.0      0.0   9.46    NaN  20230616    NaN  12.70
# 0 -1.0      0.0 -1.0      0.0   7.80    NaN  20230616    NaN  11.00
# 0  NaN      NaN  NaN      NaN   6.42    NaN  20230616    NaN   9.23
# 0  NaN      NaN  NaN      NaN   5.09    NaN  20230616    NaN   7.55
# 0  NaN      NaN  NaN      NaN  29.18    NaN  20230623    NaN  33.41
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230623    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  24.52    NaN  20230623    NaN  26.87
# 0 -1.0      0.0 -1.0      0.0   0.00    NaN  20230623    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  20.04    NaN  20230623    NaN  22.80
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230623    NaN    NaN
# 0  NaN      NaN  NaN      NaN  15.88    NaN  20230623    NaN  19.00
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230623    NaN    NaN
# 0  NaN      NaN  NaN      NaN  12.05    NaN  20230623    NaN  14.40
# 0 -1.0      0.0 -1.0      0.0   0.00    NaN  20230623    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0   8.68    NaN  20230623    NaN  12.05
# 0 -1.0      0.0 -1.0      0.0   0.00    NaN  20230623    NaN    NaN
# 0  NaN      NaN  NaN      NaN   5.87    NaN  20230623    NaN   8.70
# 0  NaN      NaN  NaN      NaN  30.29    NaN  20230630    NaN  32.27
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230630    NaN    NaN
# 0  NaN      NaN  NaN      NaN  25.69    NaN  20230630    NaN  29.82
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230630    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  21.36    NaN  20230630    NaN  24.23
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230630    NaN    NaN
# 0  NaN      NaN  NaN      NaN  17.27    NaN  20230630    NaN  20.83
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230630    NaN    NaN
# 0  NaN      NaN  NaN      NaN  13.52    NaN  20230630    NaN  16.50
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230630    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0  10.30    NaN  20230630    NaN  13.35
# 0  NaN      NaN  NaN      NaN    NaN    NaN  20230630    NaN    NaN
# 0 -1.0      0.0 -1.0      0.0   7.55    NaN  20230630    NaN  10.00
#
#    impliedVolatility  lastPirce    low  open  sigma  strike  theta  vega
# 0                NaN        NaN    NaN   NaN    NaN   305.0    NaN   NaN  \
# 0                NaN        NaN  26.85   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN  23.50   0.0    NaN   310.0    NaN   NaN
# 0                NaN        NaN  21.30   0.0    NaN   312.5    NaN   NaN
# 0                NaN        NaN  18.43   0.0    NaN   315.0    NaN   NaN
# 0                NaN        NaN  15.95   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN  13.68   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN  11.43   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN   9.30   NaN    NaN   325.0    NaN   NaN
# 0                NaN        NaN   7.50   NaN    NaN   327.5    NaN   NaN
# 0                NaN        NaN   5.64   0.0    NaN   330.0    NaN   NaN
# 0                NaN        NaN   4.20   NaN    NaN   332.5    NaN   NaN
# 0                NaN        NaN   3.05   NaN    NaN   335.0    NaN   NaN
# 0                NaN        NaN  29.15   NaN    NaN   305.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN  24.69   0.0    NaN   310.0    NaN   NaN
# 0                NaN        NaN  22.20   0.0    NaN   312.5    NaN   NaN
# 0                NaN        NaN  19.91   0.0    NaN   315.0    NaN   NaN
# 0                NaN        NaN  17.90   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN  15.25   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN  13.30   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN  11.50   0.0    NaN   325.0    NaN   NaN
# 0                NaN        NaN   9.30   0.0    NaN   327.5    NaN   NaN
# 0                NaN        NaN   7.65   0.0    NaN   330.0    NaN   NaN
# 0                NaN        NaN   6.22   NaN    NaN   332.5    NaN   NaN
# 0                NaN        NaN   4.95   NaN    NaN   335.0    NaN   NaN
# 0                NaN        NaN  31.03   NaN    NaN   305.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN  25.90   0.0    NaN   310.0    NaN   NaN
# 0                NaN        NaN    NaN   0.0    NaN   312.5    NaN   NaN
# 0                NaN        NaN  20.80   0.0    NaN   315.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN  16.09   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN  12.30   NaN    NaN   325.0    NaN   NaN
# 0                NaN        NaN    NaN   0.0    NaN   327.5    NaN   NaN
# 0                NaN        NaN   8.75   0.0    NaN   330.0    NaN   NaN
# 0                NaN        NaN    NaN   0.0    NaN   332.5    NaN   NaN
# 0                NaN        NaN   6.20   NaN    NaN   335.0    NaN   NaN
# 0                NaN        NaN  31.45   NaN    NaN   305.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   307.5    NaN   NaN
# 0                NaN        NaN  27.00   NaN    NaN   310.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   312.5    NaN   NaN
# 0                NaN        NaN  21.25   0.0    NaN   315.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   317.5    NaN   NaN
# 0                NaN        NaN  17.80   NaN    NaN   320.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   322.5    NaN   NaN
# 0                NaN        NaN  13.53   NaN    NaN   325.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   327.5    NaN   NaN
# 0                NaN        NaN  10.10   0.0    NaN   330.0    NaN   NaN
# 0                NaN        NaN    NaN   NaN    NaN   332.5    NaN   NaN
# 0                NaN        NaN   7.40   0.0    NaN   335.0    NaN   NaN
#
#    volume
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN
# 0     NaN

# %%
option_chain_rec = {'exp_date':[''],'strike':[np.nan],
                'lastPirce':[np.nan],'bid':[np.nan], 'ask':[np.nan],
                'bidSize':[np.nan], 'askSize':[np.nan], 'volume':[np.nan],
                'open':[np.nan], 'high':[np.nan], 'low':[np.nan], 'close':[np.nan],
                'impliedVolatility':[np.nan], 'delta':[np.nan], 'gamma':[np.nan],
                'vega':[np.nan], 'theta':[np.nan],'sigma':[np.nan]}
    
df = pd.DataFrame()

for exp_date in exp_date_list:
    for strike in strikes:        
        ne = pd.DataFrame.from_records(option_chain_rec)
        ne.exp_date = exp_date
        ne.strike = strike
        df = pd.concat([df, ne])
        
df

# %%
import pandas as pd
import pandas_ta as ta
import pymannkendall as mk
import math
import numpy as np
from datetime import time, date, datetime, timedelta
from pytz import timezone

max_days_to_expire = 30

exp_date_list = []

exp_tbl = x.expirations        
trade_date = datetime.now(timezone('US/Eastern'))


exp_date_list = list(filter(lambda x: (pd.Timestamp(x).tz_localize(timezone('US/Eastern'))-trade_date).days < 30, x.expirations))   
    
#for exp_date in exp_tbl:    
#    exp_date = pd.Timestamp(exp_date)
#    days_to_expire = (exp_date.tz_localize(timezone('US/Eastern'))-trade_date).days

#    if days_to_expire <= 0:
#        continue

#    if days_to_expire > max_days_to_expire:
#        break

#    exp_date_list.append(exp_date)

print(exp_date_list)

# %%
class IBConfig:
    port = 7497
    clientId = 8888
    marketDataType = 3 #https://interactivebrokers.github.io/tws-api/market_data_type.html

# %%
from ib_insync import *

class IBClient:    

    connection = None     
    
    @staticmethod
    def get_client():
        util.startLoop()  # uncomment this line when in a notebook        
        if IBClient.connection == None:
            ib = IB()
            ib.connect('127.0.0.1', IBConfig.port, clientId=IBConfig.clientId)            
            IBClient.connection = ib
            # delayed quote
            ib.reqMarketDataType(IBConfig.marketDataType)            
            return ib
        else:
            return IBClient.connection
        
    @staticmethod
    def disconnect():
        if IBClient.connection != None:
            IBClient.connection.client.disconnect()
            IBClient.connection = None

# %%
mycontract = Contract()
mycontract.symbol = "AAPL"
mycontract.secType = "STK"
mycontract.exchange = "SMART"
mycontract.currency = "USD"
        
contract = Forex('EURUSD')

ib.reqMarketDataType(3)
    
#https://interactivebrokers.github.io/tws-api/historical_bars.html#hd_what_to_show

bars = ib.reqHistoricalData(
    mycontract, endDateTime='', durationStr='1 y',
    barSizeSetting='1 day', whatToShow='TRADES', useRTH=True)

# convert to pandas dataframe:
df = util.df(bars)

df.rename(columns = {'date':'Date', 'open':'Open', 'high':'High', 'low':'Low',
                     'close':'Close', 'volume':'Volume', 'average':'Average'}, inplace = True)

print(df.set_index('Date'))

ib.disconnect()

# %%
from ib_insync import *

try:
    get_ipython    
    util.startLoop()  # uncomment this line when in a notebook
except:
    pass
    
ib = IB()

symbol = 'MSFT'

ib.connect('127.0.0.1', 7497, clientId=0)

contract = Contract()
contract.symbol =  symbol
contract.secType = "OPT"
contract.exchange = "SMART"
contract.currency = "USD"

ib.reqMarketDataType(3)
    
#https://interactivebrokers.github.io/tws-api/historical_bars.html#hd_what_to_show

x = ib.reqMatchingSymbols(symbol)


conId = x[0].contract.conId

x = ib.reqSecDefOptParams(symbol, "", "STK", conId)

print(x[0])


ib.disconnect()

# %%
x[0].contract.conId

# %%
from ib_insync import *

try:
    get_ipython    
    util.startLoop()  # uncomment this line when in a notebook
except:
    pass
    
ib = IB()

ib.connect('127.0.0.1', 7497, clientId=3)

mycontract = Contract()
mycontract.symbol = "AAPL"
mycontract.secType = "OPT"
mycontract.exchange = "SMART"
mycontract.currency = "USD"
        
contract = Forex('EURUSD')

ib.reqMarketDataType(3)
    
#https://interactivebrokers.github.io/tws-api/historical_bars.html#hd_what_to_show

x = ib.reqSecDefOptParams("MSFT", "", "STK", 272093)

print(x[0])

ib.disconnect()

# %%
#Legal interval are: 1 secs, 5 secs, 10 secs, 15 secs, 30 secs, 1 min, 
#    2 mins, 3 mins, 5 mins, 10 mins, 15 mins, 20 mins, 30 mins, 
#    1 hour, 2 hours, 3 hours, 4 hours, 8 hours, 1 day, 1W, 1M, 
                
def get_price_history(symbol, period="1 Y", interval="1 day", start=None, end=None):    

    ib = IBClient.get_client()
    
    contract = Contract()
    contract.symbol = symbol
    contract.secType = "STK"
    contract.exchange = "SMART"
    contract.currency = "USD"

    bars = ib.reqHistoricalData(
        contract, endDateTime='', durationStr=period,
        barSizeSetting=interval, whatToShow='TRADES', useRTH=True)

    df =  util.df(bars)
    df.rename(columns = {'date':'Date', 'open':'Open', 'high':'High', 'low':'Low',
                         'close':'Close', 'volume':'Volume', 'average':'Average'}, inplace = True)
    
    IBClient.disconnect()
    
    return df.set_index('Date')

get_price_history('AAPL')

# %%
apple_contract = Contract()
apple_contract.symbol = 'MSFT'
apple_contract.secType = 'STK'
apple_contract.exchange = 'SMART'
apple_contract.currency = 'USD'


#Request Market Data
app.reqMarketDataType(3)
app.reqMktData(1, apple_contract, '', False, False, [])

contract.lastTradeDateOrContractMonth = '20230519'
contract.strike = 305.0
contract.right = 'C'
contract.multiplier = '100'

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect('127.0.0.1', 7497, clientId=4)

contract = Contract()
contract.symbol = 'MSFT'
contract.secType = 'OPT'
contract.exchange = 'SMART'
contract.currency = 'USD'
contract.lastTradeDateOrContractMonth = '20230519'
contract.strike = 307.5
contract.right = 'C'
contract.multiplier = '100'
ib.qualifyContracts(contract) 
ib.reqMarketDataType(3)
x = ib.reqMktData(contract, '', False, False, [])
ib.sleep(5)

print(vars(x))

ib.disconnect()

# convert to pandas dataframe:
#df = util.df(bars)
#print(df)

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

def get_ticker(symbol):
    
    ib = IB()
    ib.connect('127.0.0.1', 7497, clientId=4)

    contract = Contract()
    contract.symbol = symbol
    contract.secType = 'STK'
    contract.exchange = 'SMART'
    contract.currency = 'USD'

    ib.qualifyContracts(contract) 
    ib.reqMarketDataType(3)
    x = ib.reqMktData(contract, '', False, False, [])
    ib.sleep(5)

    #return x.bid, x.ask, x.last, x.bidGreeks.impliedVol, x.bidGreeks.delta, x.bidGreeks.gamma, x.bidGreeks.vega, x.bidGreeks.theta

    ib.disconnect()

    return x

x = get_ticker('AAPL')    

print(vars(x))

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

def get_option_price(symbol, exp_date, strike, otype):
    
    ib = IB()
    ib.connect('127.0.0.1', 7497, clientId=4)

    contract = Contract()
    contract.symbol = symbol
    contract.secType = 'OPT'
    contract.exchange = 'SMART'
    contract.currency = 'USD'
    contract.lastTradeDateOrContractMonth = exp_date #'20230512'
    contract.strike = strike
    contract.right = otype
    contract.multiplier = '100'
    ib.qualifyContracts(contract) 
    ib.reqMarketDataType(3)
    x = ib.reqMktData(contract, '', False, False, [])
    ib.sleep(5)
    
    return x.bid, x.ask, x.last, x.bidGreeks.impliedVol, x.bidGreeks.delta, x.bidGreeks.gamma, x.bidGreeks.vega, x.bidGreeks.theta

    ib.disconnect()

get_option_price('AAPL', '20230512', 172.5, 'C')

# %%
#https://algotrading101.com/learn/ib_insync-interactive-brokers-api-guide/

from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect()

# %%
nflx_contract = Stock('NFLX', 'SMART', 'USD')

# %%
ib.qualifyContracts(nflx_contract)

# %%
data = ib.reqMktData(nflx_contract)

# %%
data.marketPrice()

# %%
eur_usd_contract = Forex('EURUSD', 'IDEALPRO')
ib.qualifyContracts(eur_usd_contract)

# %%
btc_fut_contract = Future('BRR', '20231031', 'CMECRYPTO')
ib.qualifyContracts(btc_fut_contract)

# %%
btc_fut_cont_contract = ContFuture('BRR', 'CMECRYPTO')
ib.qualifyContracts(btc_fut_cont_contract)

# %%
ib.reqMarketDataType(3)

historical_data_nflx = ib.reqHistoricalData(
    nflx_contract, 
    '', 
    barSizeSetting='15 mins', 
    durationStr='2 D', 
    whatToShow='MIDPOINT', 
    useRTH=True
    )

# %%
type(historical_data_nflx)

# %%
historical_data_nflx[-1]

# %%
util.df(historical_data_nflx)

# %%
nflx_order = MarketOrder('BUY', 200)

# %%
trade = ib.placeOrder(nflx_contract, nflx_order)

# %%
def order_status(trade):
    print(trade.orderStatis.status)
    if trade.orderStatus.status == 'Filled':
        fill = trade.fills[-1]
        
        print(f'{fill.time} - {fill.execution.side} {fill.contract.symbol} {fill.execution.shares} @ {fill.execution.avgPrice}')

# %%
from ib_insync import *

def order_status(trade):
    print(trade.orderStatis.status)
    if trade.orderStatus.status == 'Filled':
        fill = trade.fills[-1]
        
        print(f'{fill.time} - {fill.execution.side} {fill.contract.symbol} {fill.execution.shares} @ {fill.execution.avgPrice}')
        
util.startLoop()  # uncomment this line when in a noteboo
nflx_order = MarketOrder('BUY', 100)
msft_order = MarketOrder('BUY', 100)

nflx_trade = ib.placeOrder(nflx_contract, nflx_order)

trade.filledEvent+= order_status

# %%
eurusd_bracket_order = ib.bracketOrder(
    'BUY',
    100000,
    limitPrice=1.19,
    takeProfitPrice=1.20,
    stopLossPrice=1.18
)

# %%
for ord in eurusd_bracket_order:
    ib.placeOrder(eur_usd_contract, ord)

# %%
visa_contract = Stock('V', 'SMART', 'USD')
ib.qualifyContracts(visa_contract)

# %%
price_condition = PriceCondition(
    price=200,
    conId=visa_contract.conId,
    exch=visa_contract.exchange
    )

# %%
ma_contract = Stock('MA', 'SMART', 'USD')
ib.qualifyContracts(ma_contract)

# %%
from ib_insync import *

util.startLoop()  # uncomment this line when in a notebook

ib = IB()

ib.connect('127.0.0.1', 7497, clientId=123)

# %%
P1S_contract = Option('MSFT', '20230519', 290, 'C', 'SMART')
ib.qualifyContracts(P1S_contract) 
P1L_contract = Option('MSFT', '20230519', 300, 'C', 'SMART')
ib.qualifyContracts(P1L_contract) 

P1S_contract.ratio = 1
P1S_contract.action = 'SELL'
P1S_contract.openClose = 0
P1S_contract.shortSaleSlot = 0
P1S_contract.exemptCode=0
P1S_contract.designatedLocation = 0   

P1L_contract.ratio = 1
P1L_contract.action = 'BUY'
P1L_contract.openClose = 0
P1L_contract.shortSaleSlot = 0
P1L_contract.exemptCode=0
P1L_contract.designatedLocation = 0

# %%
comboLegs = [P1S_contract, P1L_contract]

# %%
contract = Contract(symbol='MSFT', secType='BAG', exchange='SMART', currency='USD', comboLegs=comboLegs)

# %%
order = Order(action='BUY', orderType='LMT', totalQuantity=5, lmtPrice=8)

# %%
trade = ib.placeOrder(contract, order)

def order_status(trade):
    print(trade.orderStatus.status)
    if trade.orderStatus.status == 'Filled':
        fill = trade.fills[-1]
        
        print(f'{fill.time} - {fill.execution.side} {fill.contract.symbol} {fill.execution.shares} @ {fill.execution.avgPrice}')
        

trade.filledEvent+= order_status

# %%
trade.orderStatus

# %%
trade.log

# %%
ib.cancelOrder(order)

# %%
trade

# %%
order.orderId

# %%
list = [1,2,3]

# %%
list.pop(1)

# %%
x = ib.portfolio(account='DU7131629')
p = util.df(x)
p

# %%
x = ib.accountValues(account='')
df = util.df(x)
for index, row in df.iterrows():
    print(row['tag'], '\t----\t', row['value'])

# %%
ib.managedAccounts()

# %%
x = ib.accountSummary()
df = util.df(x)

for index, row in df.iterrows():
    print(row['tag'], '\t----\t', row['value'])

# %%
util.df(ib.positions())

# %%
util.df(ib.orders())

# %%
util.df(ib.fills())

# %%
dir(ib)

# %%
import sys
import traceback
#sys.exc_info()
#traceback.format_exc(sys.exc_info()) 

etype, value, tb = sys.exc_info()

print(''.join(traceback.format_exception(etype, value, tb, limit)))

# %%
import traceback
import sys
from pprint import pprint

#from traceback_example import produce_exception

try:
    produce_exception()
except Exception as err:
    #tb = traceback.TracebackException.from_exception(err)

    #print('Handled at stack lvl 0')
    #print(''.join(tb.stack.format()))    
    
    exc_type, exc_value, exc_tb = sys.exc_info()
    print(exc_type)
    print(exc_value)
    #print(exc_tb)
    print(traceback.format_exception(exc_type, exc_value, exc_tb))
    #print(exc_tb.tb_frame)
    #print(exc_tb.tb_lasti)
    #print(exc_tb.tb_lineno)
    #print(exc_tb.tb_next)

# %%
import traceback

try:
    1/0
except Exception as ex:
    print(ex)
    print(traceback.format_exc())
    # or
    #print(sys.exc_info()[2])    
    #x = traceback.print_exception(type(ex), ex, ex.__traceback__)
    #print(ex.__traceback__)

# %%
from ib_insync import *

util.startLoop()  # only use in interactive environments (i.e. Jupyter Notebooks)

# %%
ib = IB()
#ib.connect()

ib.connect("127.0.0.1", 4002, clientId=21,account='DU7131629')

# %%
ib = IB()
util.logToConsole('DEBUG')
ib.connect(host='127.0.0.1', port=7497, clientId=1)
