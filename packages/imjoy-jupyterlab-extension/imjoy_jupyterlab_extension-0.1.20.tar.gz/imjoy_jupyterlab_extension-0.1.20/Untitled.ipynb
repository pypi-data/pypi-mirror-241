# %%
from imjoy_rpc import api

class ImJoyPlugin():
    async def setup(self):
        pass

    async def run(self, ctx):
        viewer = await api.createWindow(src="https://kaibu.org/#/app")

        await viewer.view_image("https://images.proteinatlas.org/61448/1319_C10_2_blue_red_green.jpg")

api.export(ImJoyPlugin())
# Out:
# <div id="e4adf886-20b3-4ebd-87b9-1db596b1955d"></div>
# <_GatheringFuture pending>

# %%
from itkwidgets import view
import numpy as np
image = np.random.randint(0,255, (256, 256, 3))
view(image)
# Out:
#                 <img id="screenshot_imjoy_window_94b9bfc9-5af6-4df5-bd48-fbb6f3a1f7d6" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_94b9bfc9-5af6-4df5-bd48-fbb6f3a1f7d6");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_94b9bfc9-5af6-4df5-bd48-fbb6f3a1f7d6");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="bb85b50d-f6b7-4866-8fa9-b16ba790e1f8"></div>
